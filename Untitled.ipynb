# %%
bucket = 'vxw6ta-sagemaker'
prefix = 'sagemaker/xgboost_credit_risk'

# Define IAM role
import boto3
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.serializers import CSVSerializer

role = get_execution_role()

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# Out:
# --2021-04-21 06:00:12--  https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5539328 (5.3M) [application/x-httpd-php]
# Saving to: ‘default of credit card clients.xls’
#
# default of credit c 100%[===================>]   5.28M  7.96MB/s    in 0.7s
#
# 2021-04-21 06:00:13 (7.96 MB/s) - ‘default of credit card clients.xls’ saved [5539328/5539328]

# %%
dataset = pd.read_excel('default of credit card clients.xls')
pd.set_option('display.max_rows', 8)
pd.set_option('display.max_columns', 15)
dataset
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6  ...  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  ...
# 1              1      20000    2          2         1   24      2  ...
# 2              2     120000    2          2         2   26     -1  ...
# 3              3      90000    2          2         2   34      0  ...
# ...          ...        ...  ...        ...       ...  ...    ...  ...
# 29997      29997     150000    1          3         2   43     -1  ...
# 29998      29998      30000    1          2         2   37      4  ...
# 29999      29999      80000    1          3         1   41      1  ...
# 30000      30000      50000    1          2         1   46      0  ...
#
#             X18       X19       X20       X21       X22       X23  \
# 0      PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 1             0       689         0         0         0         0
# 2             0      1000      1000      1000         0      2000
# 3          1518      1500      1000      1000      1000      5000
# ...         ...       ...       ...       ...       ...       ...
# 29997      1837      3526      8998       129         0         0
# 29998         0         0     22000      4200      2000      3100
# 29999     85900      3409      1178      1926     52964      1804
# 30000      2078      1800      1430      1000      1000      1000
#
#                                 Y
# 0      default payment next month
# 1                               1
# 2                               1
# 3                               0
# ...                           ...
# 29997                           0
# 29998                           1
# 29999                           1
# 30000                           1
#
# [30001 rows x 25 columns]

# %%
dataset = dataset.drop('Unnamed: 0', axis=1)
dataset = pd.concat([dataset['Y'], dataset.drop(['Y'], axis=1)], axis=1)

# %%
train_data, validation_data, test_data = np.split(dataset.sample(frac=1, random_state=1729), [int(0.7 * len(dataset)), int(0.9 * len(dataset))])
train_data.to_csv('train.csv', header=False, index=False)
validation_data.to_csv('validation.csv', header=False, index=False)

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')
s3_input_train = TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

# %%
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'}

sess = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                    role, 
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(eta=0.1, objective='binary:logistic', num_round=25) 
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2021-04-21 06:03:53 Starting - Starting the training job...
# 2021-04-21 06:04:17 Starting - Launching requested ML instancesProfilerReport-1618985033: InProgress
# ......
# 2021-04-21 06:05:17 Starting - Preparing the instances for training.........
# 2021-04-21 06:06:46 Downloading - Downloading input data
# 2021-04-21 06:06:46 Training - Downloading the training image..
# 2021-04-21 06:07:21 Uploading - Uploading generated training model
# 2021-04-21 06:07:21 Completed - Training job completed
# Arguments: train
# [2021-04-21:06:07:08:INFO] Running standalone xgboost training.
# [2021-04-21:06:07:08:INFO] File size need to be processed in the node: 2.32mb. Available memory size in the node: 8416.72mb
# [2021-04-21:06:07:08:INFO] Determined delimiter of CSV input is ','
# [06:07:08] S3DistributionType set as FullyReplicated
# [06:07:08] 21000x23 matrix with 483000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-04-21:06:07:08:INFO] Determined delimiter of CSV input is ','
# [06:07:08] S3DistributionType set as FullyReplicated
# [06:07:08] 6000x23 matrix with 138000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-error:0.173619#011validation-error:0.181
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-error:0.173143#011validation-error:0.176667
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-error:0.172857#011validation-error:0.176167
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-error:0.17119#011validation-error:0.176333
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-error:0.170143#011validation-error:0.175667
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-error:0.169381#011validation-error:0.176833
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-error:0.169#011validation-error:0.176667
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-error:0.168619#011validation-error:0.177167
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-error:0.168286#011validation-error:0.177333
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-error:0.168095#011validation-error:0.176167
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-error:0.168143#011validation-error:0.177833
# [06:07:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-error:0.16781#011validation-error:0.177833
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-error:0.167#011validation-error:0.178667
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-error:0.166667#011validation-error:0.177167
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-error:0.166095#011validation-error:0.177667
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-error:0.16581#011validation-error:0.177833
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-error:0.165714#011validation-error:0.178667
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-error:0.164571#011validation-error:0.178333
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-error:0.164476#011validation-error:0.179167
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-error:0.164#011validation-error:0.179667
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-error:0.163238#011validation-error:0.1795
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-error:0.163286#011validation-error:0.179833
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-error:0.162571#011validation-error:0.179333
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-error:0.16219#011validation-error:0.178333
# [06:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-error:0.161762#011validation-error:0.178833
# Training seconds: 52
# Billable seconds: 52

# %%
xgb_predictor = xgb.deploy(
	initial_instance_count = 1,
	instance_type = 'ml.m4.xlarge',
	serializer = CSVSerializer())
# Out:
# -----------------!

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data.to_numpy()[:,1:])
predictions
# Out:
# array([0.10145303, 0.29316297, 0.70782304, ..., 0.15233986, 0.38610485,
#        0.10773233])

# %%
# import libraries
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   

# Define IAM role
role = get_execution_role()
prefix = 'sagemaker/DEMO-xgboost-dm'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # each region has its XGBoost container
my_region = boto3.session.Session().region_name # set the region of the instance
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-east-1 region. You will use the 811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
bucket_name = 'vxw6ta-sagemaker' # <--- CHANGE THIS VARIABLE TO A UNIQUE NAME FOR YOUR BUCKET
s3 = boto3.resource('s3')
try:
    if  my_region == 'us-east-1':
      s3.create_bucket(Bucket=bucket_name)
    else: 
      s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={ 'LocationConstraint': my_region })
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# S3 bucket created successfully

# %%
try:
  urllib.request.urlretrieve ("https://d1.awsstatic.com/tmt/build-train-deploy-machine-learning-model-sagemaker/bank_clean.27f01fbbdf43271788427f3682996ae29ceca05d.csv", "bank_clean.csv")
  print('Success: downloaded bank_clean.csv.')
except Exception as e:
  print('Data load error: ',e)

try:
  model_data = pd.read_csv('./bank_clean.csv',index_col=0)
  print('Success: Data loaded into dataframe.')
except Exception as e:
    print('Data load error: ',e)
# Out:
# Success: downloaded bank_clean.csv.
# Success: Data loaded into dataframe.

# %%
train_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data))])
print(train_data.shape, test_data.shape)
# Out:
# (28831, 61) (12357, 61)

# %%
pd.concat([train_data['y_yes'], train_data.drop(['y_no', 'y_yes'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
sess = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[my_region],role, instance_count=1, instance_type='ml.m4.xlarge',output_path='s3://{}/{}/output'.format(bucket_name, prefix),sagemaker_session=sess)
xgb.set_hyperparameters(max_depth=5,eta=0.2,gamma=4,min_child_weight=6,subsample=0.8,silent=0,objective='binary:logistic',num_round=100)

# %%
xgb.fit({'train': s3_input_train})
# Out:
# 2021-04-21 06:35:37 Starting - Starting the training job...
# 2021-04-21 06:36:00 Starting - Launching requested ML instancesProfilerReport-1618986937: InProgress
# .........
# 2021-04-21 06:37:21 Starting - Preparing the instances for training.........
# 2021-04-21 06:39:01 Downloading - Downloading input data
# 2021-04-21 06:39:01 Training - Downloading the training image...
# 2021-04-21 06:39:34 Uploading - Uploading generated training modelArguments: train
# [2021-04-21:06:39:24:INFO] Running standalone xgboost training.
# [2021-04-21:06:39:24:INFO] Path /opt/ml/input/data/validation does not exist!
# [2021-04-21:06:39:24:INFO] File size need to be processed in the node: 3.38mb. Available memory size in the node: 8426.58mb
# [2021-04-21:06:39:24:INFO] Determined delimiter of CSV input is ','
# [06:39:24] S3DistributionType set as FullyReplicated
# [06:39:24] 28831x59 matrix with 1701029 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [06:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [0]#011train-error:0.100482
# [06:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [1]#011train-error:0.099858
# [06:39:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 22 pruned nodes, max_depth=5
# [2]#011train-error:0.099754
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 14 pruned nodes, max_depth=5
# [3]#011train-error:0.099095
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=5
# [4]#011train-error:0.098991
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=5
# [5]#011train-error:0.099303
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 18 pruned nodes, max_depth=5
# [6]#011train-error:0.099684
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 22 pruned nodes, max_depth=5
# [7]#011train-error:0.09906
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 20 pruned nodes, max_depth=5
# [8]#011train-error:0.098852
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 8 pruned nodes, max_depth=5
# [9]#011train-error:0.098679
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [10]#011train-error:0.098748
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 24 pruned nodes, max_depth=5
# [11]#011train-error:0.098748
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 22 pruned nodes, max_depth=5
# [12]#011train-error:0.098748
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [13]#011train-error:0.09854
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 20 pruned nodes, max_depth=5
# [14]#011train-error:0.098574
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 20 pruned nodes, max_depth=5
# [15]#011train-error:0.098609
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 16 pruned nodes, max_depth=5
# [16]#011train-error:0.098817
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [17]#011train-error:0.098817
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 18 pruned nodes, max_depth=5
# [18]#011train-error:0.098679
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 16 pruned nodes, max_depth=5
# [19]#011train-error:0.098679
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [20]#011train-error:0.098713
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [21]#011train-error:0.098505
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [22]#011train-error:0.098401
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [23]#011train-error:0.098332
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [24]#011train-error:0.098332
# [06:39:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [25]#011train-error:0.09795
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [26]#011train-error:0.098262
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=5
# [27]#011train-error:0.098193
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 24 pruned nodes, max_depth=3
# [28]#011train-error:0.097985
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [29]#011train-error:0.097499
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [30]#011train-error:0.097638
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 22 pruned nodes, max_depth=5
# [31]#011train-error:0.097395
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 24 pruned nodes, max_depth=5
# [32]#011train-error:0.097222
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=5
# [33]#011train-error:0.097118
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=5
# [34]#011train-error:0.097014
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 18 pruned nodes, max_depth=5
# [35]#011train-error:0.09684
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [36]#011train-error:0.096667
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 18 pruned nodes, max_depth=5
# [37]#011train-error:0.096736
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 22 pruned nodes, max_depth=5
# [38]#011train-error:0.096563
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=5
# [39]#011train-error:0.096355
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 36 pruned nodes, max_depth=3
# [40]#011train-error:0.096285
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 38 pruned nodes, max_depth=4
# [41]#011train-error:0.096528
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 16 pruned nodes, max_depth=4
# [42]#011train-error:0.096355
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 26 pruned nodes, max_depth=5
# [43]#011train-error:0.096459
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 36 pruned nodes, max_depth=5
# [44]#011train-error:0.096355
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 34 pruned nodes, max_depth=2
# [45]#011train-error:0.096216
# [06:39:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 20 pruned nodes, max_depth=5
# [46]#011train-error:0.096077
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [47]#011train-error:0.0958
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [48]#011train-error:0.095904
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 16 pruned nodes, max_depth=5
# [49]#011train-error:0.095904
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 34 pruned nodes, max_depth=4
# [50]#011train-error:0.095834
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 16 pruned nodes, max_depth=5
# [51]#011train-error:0.095765
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [52]#011train-error:0.095904
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [53]#011train-error:0.095834
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 22 pruned nodes, max_depth=5
# [54]#011train-error:0.095834
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=5
# [55]#011train-error:0.09573
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 30 pruned nodes, max_depth=5
# [56]#011train-error:0.095626
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [57]#011train-error:0.095696
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 28 pruned nodes, max_depth=5
# [58]#011train-error:0.095661
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 24 pruned nodes, max_depth=4
# [59]#011train-error:0.095592
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 16 pruned nodes, max_depth=5
# [60]#011train-error:0.095522
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 16 pruned nodes, max_depth=4
# [61]#011train-error:0.095383
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 20 pruned nodes, max_depth=4
# [62]#011train-error:0.095314
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 26 pruned nodes, max_depth=5
# [63]#011train-error:0.095661
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 32 pruned nodes, max_depth=4
# [64]#011train-error:0.095661
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 18 pruned nodes, max_depth=5
# [65]#011train-error:0.095418
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 36 pruned nodes, max_depth=3
# [66]#011train-error:0.095314
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [67]#011train-error:0.095349
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 28 pruned nodes, max_depth=3
# [68]#011train-error:0.095314
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 28 pruned nodes, max_depth=0
# [69]#011train-error:0.095314
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 32 pruned nodes, max_depth=3
# [70]#011train-error:0.095383
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 12 pruned nodes, max_depth=5
# [71]#011train-error:0.095453
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [72]#011train-error:0.095349
# [06:39:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 24 pruned nodes, max_depth=4
# [73]#011train-error:0.095245
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [74]#011train-error:0.095175
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 18 pruned nodes, max_depth=4
# [75]#011train-error:0.095071
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 22 pruned nodes, max_depth=5
# [76]#011train-error:0.095175
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 30 pruned nodes, max_depth=5
# [77]#011train-error:0.095002
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=4
# [78]#011train-error:0.095037
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 32 pruned nodes, max_depth=5
# [79]#011train-error:0.095037
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=5
# [80]#011train-error:0.095002
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 20 pruned nodes, max_depth=5
# [81]#011train-error:0.094794
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=5
# [82]#011train-error:0.094759
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 20 pruned nodes, max_depth=5
# [83]#011train-error:0.094933
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [84]#011train-error:0.09469
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 22 pruned nodes, max_depth=5
# [85]#011train-error:0.094759
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 24 pruned nodes, max_depth=5
# [86]#011train-error:0.094482
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 16 pruned nodes, max_depth=5
# [87]#011train-error:0.094447
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [88]#011train-error:0.094482
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 24 pruned nodes, max_depth=5
# [89]#011train-error:0.094378
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 28 pruned nodes, max_depth=0
# [90]#011train-error:0.094343
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 28 pruned nodes, max_depth=4
# [91]#011train-error:0.094274
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 20 pruned nodes, max_depth=5
# [92]#011train-error:0.094239
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 32 pruned nodes, max_depth=5
# [93]#011train-error:0.094169
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 28 pruned nodes, max_depth=5
# [94]#011train-error:0.094169
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [95]#011train-error:0.094204
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 28 pruned nodes, max_depth=0
# [96]#011train-error:0.094204
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 20 pruned nodes, max_depth=5
# [97]#011train-error:0.093927
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 38 pruned nodes, max_depth=0
# [98]#011train-error:0.093927
# [06:39:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 32 pruned nodes, max_depth=0
# [99]#011train-error:0.093892
#
# 2021-04-21 06:40:01 Completed - Training job completed
# ProfilerReport-1618986937: NoIssuesFound
# Training seconds: 62
# Billable seconds: 62

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# ---------------!

# %%
from sagemaker.serializers import CSVSerializer

test_data_array = test_data.drop(['y_no', 'y_yes'], axis=1).values #load the data into an array
xgb_predictor.serializer = CSVSerializer() # set the serializer type
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (12357,)

# %%
cm = pd.crosstab(index=test_data['y_yes'], columns=np.round(predictions_array), rownames=['Observed'], colnames=['Predicted'])
tn = cm.iloc[0,0]; fn = cm.iloc[1,0]; tp = cm.iloc[1,1]; fp = cm.iloc[0,1]; p = (tp+tn)/(tp+tn+fp+fn)*100
print("\n{0:<20}{1:<4.1f}%\n".format("Overall Classification Rate: ", p))
print("{0:<15}{1:<15}{2:>8}".format("Predicted", "No Purchase", "Purchase"))
print("Observed")
print("{0:<15}{1:<2.0f}% ({2:<}){3:>6.0f}% ({4:<})".format("No Purchase", tn/(tn+fn)*100,tn, fp/(tp+fp)*100, fp))
print("{0:<16}{1:<1.0f}% ({2:<}){3:>7.0f}% ({4:<}) \n".format("Purchase", fn/(tn+fn)*100,fn, tp/(tp+fp)*100, tp))
# Out:
# Overall Classification Rate: 89.5%
#
# Predicted      No Purchase    Purchase
# Observed
# No Purchase    90% (10769)    37% (167)
# Purchase        10% (1133)     63% (288)

# %%
bucket = 'vxw6ta-sagemaker'
prefix = 'sagemaker/xgboost_credit_risk'

# Define IAM role
import boto3
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sagemaker
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.serializers import CSVSerializer

role = get_execution_role()

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# Out:
# --2021-04-21 06:51:18--  https://archive.ics.uci.edu/ml/machine-learning-databases/00350/default%20of%20credit%20card%20clients.xls
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5539328 (5.3M) [application/x-httpd-php]
# Saving to: ‘default of credit card clients.xls.1’
#
# default of credit c 100%[===================>]   5.28M  8.13MB/s    in 0.6s
#
# 2021-04-21 06:51:19 (8.13 MB/s) - ‘default of credit card clients.xls.1’ saved [5539328/5539328]

# %%
dataset = pd.read_excel('default of credit card clients.xls')
pd.set_option('display.max_rows', 8)
pd.set_option('display.max_columns', 15)
dataset
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6  ...  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  ...
# 1              1      20000    2          2         1   24      2  ...
# 2              2     120000    2          2         2   26     -1  ...
# 3              3      90000    2          2         2   34      0  ...
# ...          ...        ...  ...        ...       ...  ...    ...  ...
# 29997      29997     150000    1          3         2   43     -1  ...
# 29998      29998      30000    1          2         2   37      4  ...
# 29999      29999      80000    1          3         1   41      1  ...
# 30000      30000      50000    1          2         1   46      0  ...
#
#             X18       X19       X20       X21       X22       X23  \
# 0      PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 1             0       689         0         0         0         0
# 2             0      1000      1000      1000         0      2000
# 3          1518      1500      1000      1000      1000      5000
# ...         ...       ...       ...       ...       ...       ...
# 29997      1837      3526      8998       129         0         0
# 29998         0         0     22000      4200      2000      3100
# 29999     85900      3409      1178      1926     52964      1804
# 30000      2078      1800      1430      1000      1000      1000
#
#                                 Y
# 0      default payment next month
# 1                               1
# 2                               1
# 3                               0
# ...                           ...
# 29997                           0
# 29998                           1
# 29999                           1
# 30000                           1
#
# [30001 rows x 25 columns]

# %%
dataset = dataset.drop('Unnamed: 0', axis=1)
dataset = pd.concat([dataset['Y'], dataset.drop(['Y'], axis=1)], axis=1)

# %%
train_data, validation_data, test_data = np.split(dataset.sample(frac=1, random_state=1729), [int(0.7 * len(dataset)), int(0.9 * len(dataset))])
train_data.to_csv('train.csv', header=False, index=False)
validation_data.to_csv('validation.csv', header=False, index=False)

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('validation.csv')
s3_input_train = TrainingInput(s3_data='s3://{}/{}/train'.format(bucket, prefix), content_type='csv')
s3_input_validation = TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='csv')

# %%
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'}

sess = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                    role, 
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
xgb.set_hyperparameters(eta=0.1, objective='binary:logistic', num_round=25) 
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2021-04-21 06:52:31 Starting - Starting the training job...
# 2021-04-21 06:52:54 Starting - Launching requested ML instancesProfilerReport-1618987951: InProgress
# ......
# 2021-04-21 06:53:55 Starting - Preparing the instances for training.........
# 2021-04-21 06:55:30 Downloading - Downloading input data
# 2021-04-21 06:55:30 Training - Downloading the training image...
# 2021-04-21 06:55:55 Uploading - Uploading generated training modelArguments: train
# [2021-04-21:06:55:51:INFO] Running standalone xgboost training.
# [2021-04-21:06:55:51:INFO] File size need to be processed in the node: 2.32mb. Available memory size in the node: 8412.17mb
# [2021-04-21:06:55:51:INFO] Determined delimiter of CSV input is ','
# [06:55:51] S3DistributionType set as FullyReplicated
# [06:55:51] 21000x23 matrix with 483000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-04-21:06:55:51:INFO] Determined delimiter of CSV input is ','
# [06:55:51] S3DistributionType set as FullyReplicated
# [06:55:51] 6000x23 matrix with 138000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-error:0.173619#011validation-error:0.181
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-error:0.173143#011validation-error:0.176667
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-error:0.172857#011validation-error:0.176167
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-error:0.17119#011validation-error:0.176333
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-error:0.170143#011validation-error:0.175667
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-error:0.169381#011validation-error:0.176833
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-error:0.169#011validation-error:0.176667
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-error:0.168619#011validation-error:0.177167
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-error:0.168286#011validation-error:0.177333
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-error:0.168095#011validation-error:0.176167
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-error:0.168143#011validation-error:0.177833
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-error:0.16781#011validation-error:0.177833
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-error:0.167#011validation-error:0.178667
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-error:0.166667#011validation-error:0.177167
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-error:0.166095#011validation-error:0.177667
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-error:0.16581#011validation-error:0.177833
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-error:0.165714#011validation-error:0.178667
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-error:0.164571#011validation-error:0.178333
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-error:0.164476#011validation-error:0.179167
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-error:0.164#011validation-error:0.179667
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-error:0.163238#011validation-error:0.1795
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-error:0.163286#011validation-error:0.179833
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-error:0.162571#011validation-error:0.179333
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-error:0.16219#011validation-error:0.178333
# [06:55:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-error:0.161762#011validation-error:0.178833
#
# 2021-04-21 06:56:15 Completed - Training job completed
# Training seconds: 56
# Billable seconds: 56

# %%
xgb_predictor = xgb.deploy(
	initial_instance_count = 1,
	instance_type = 'ml.m4.xlarge',
	serializer = CSVSerializer())
# Out:
# -----------------!

# %%
def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(test_data.to_numpy()[:,1:])
predictions
# Out:
# array([0.10145303, 0.29316297, 0.70782304, ..., 0.15233986, 0.38610485,
#        0.10773233])

# %%
predictions = predict(test_data.to_numpy()[:,1:])
predictions
# Out:
# array([0.10145303, 0.29316297, 0.70782304, ..., 0.15233986, 0.38610485,
#        0.10773233])

# %%
from sagemaker.serializers import CSVSerializer

test_data_array = test_data.drop(['Y'], axis=1).values #load the data into an array
xgb_predictor.serializer = CSVSerializer() # set the serializer type
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (3001,)

# %%
cm = pd.crosstab(index=test_data['Y'], columns=np.round(predictions_array), rownames=['Observed'], colnames=['Predicted'])
tn = cm.iloc[0,0]; fn = cm.iloc[1,0]; tp = cm.iloc[1,1]; fp = cm.iloc[0,1]; p = (tp+tn)/(tp+tn+fp+fn)*100
print("\n{0:<20}{1:<4.1f}%\n".format("Overall Classification Rate: ", p))
print("{0:<15}{1:<15}{2:>8}".format("Predicted", "No Default", "Default"))
print("Observed")
print("{0:<15}{1:<2.0f}% ({2:<}){3:>6.0f}% ({4:<})".format("No Default", tn/(tn+fn)*100,tn, fp/(tp+fp)*100, fp))
print("{0:<16}{1:<1.0f}% ({2:<}){3:>7.0f}% ({4:<}) \n".format("Default", fn/(tn+fn)*100,fn, tp/(tp+fp)*100, tp))
# Out:
# Overall Classification Rate: 82.1%
#
# Predicted      No Default      Default
# Observed
# No Default     84% (2245)    33% (107)
# Default         16% (429)     67% (220)

# %%
xgb_predictor.delete_endpoint()
